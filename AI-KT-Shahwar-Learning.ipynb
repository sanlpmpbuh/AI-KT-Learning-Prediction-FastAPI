# %% [markdown]
# **Why Python?**
#
# 1. Software Quality (better readability, reusability, maintainability).
# 2. Developer Productivity (1/3 to 1/5 of Size of Java or C++ code,Therefore less to type, debug, maintain).
# 3. Support Libraries.
# 4. Integration (libraries or components of java,c++,c etc).
# 5. "Fits your Brain" (said in recent python conference, easy to learn).

# %% [markdown]
# **Is Python "Scripting Language"?**
#
#
#
# * Python is a general-purpose programming language that is often applied in scripting roles.
# * It is OOP language and also SCRIPTING language. (Object-Oriented Scripting Language)

# %% [markdown]
# **The Downside:**
#
#
# *   The EXECUTION speed less.
# *   Not as fast as compiled languages like C and C++.

# %% [markdown]
# **Who Uses?**
#
# 1.   Google (web search systems).
# 2.   YouTube (video sharing service).
# 3.   Intel,Cisco,HP (Hardware testing).

# %% [markdown]
# **Technical Strengths of Python:**
# 1. Object-Oriented.
# 2. Open-Source
# 3. Portability (Linux,Unix,Windows,DOS,Mac OS)

# %% [markdown]
# **Powerful Python?**
#
#
# 1.   Type and Size need not be mentioned.
# 2.   Automatic Memory Management
# 3.   Built-in-Tools

# %% [markdown]
# **Python Vs Perl ?**
# * Python (because more readibility)
# * And Python syntax will force you to write readable code.

# %% [markdown]
# **Python Interpreter**
# *  An interpreter is
# a kind of program that executes other programs.
# * Interpreter is a layer of software logic between your code and the computer
# hardware on your machine.
# * Python Package when installed has (interpreter and support libraries).
# * Python Interpreter is implemented in C or Java (helps run java program.)

# %%
#Let's Script..!

print('AI-KT-Learning')
# Out:
# AI-KT-Learning

# %%
#print a calculation (base to the power)

print      (2**100) #here spaces did not matter
# Out:
# 1267650600228229401496703205376

# %% [markdown]
# **Execution Flow**
#
# * Python first compiles your source code (the statements in your file) into a format known
# as byte code.
# * Byte code is a lower-level,
# platform-independent representation of your source code.
# * This compilation is just Translation.
# * These byte code (extn : .pyc), translated from source code (.py).
# * Every time you save your script, new byte code is created.
# * Every time time you exit, byte codes are discarded.

# %% [markdown]
# **Why this conversion?**
#
# 1. To speed up the
# execution— Byte code can be run much more quickly than the original source code(lines of script).

# %% [markdown]
# **PVM**
# * Python Virtual Machine
# * It's a loop
# * Iterates over the byte codes
# * Runtime Engine of Python.
# * Compilation and Execution of Python Code is in one and the same time.
# *  Operations such as the creation of functions and classes
# and the linkage of modules. Such events occur before execution in more static languages, but happen as programs execute in Python.
# * ![Screenshot%20%28106%29.png](attachment:Screenshot%20%28106%29.png)

# %%
# !!!!----INTERACTIVE PROMT----!!!!
# codes can be run in command line.
# this is interactive prompt

my_name = 'Shahwar Alam Naqvi'
my_name
# Out:
# 'Shahwar Alam Naqvi'

# %%
# test

'Alam!'*8
# Out:
# 'Alam!Alam!Alam!Alam!Alam!Alam!Alam!Alam!'

# %% [markdown]
# **Why and Why Not the Interactive Prompt?**
# * Instant output on the fly.
# * We can test several codes.
# * Print keyword not required, directly write expression.
# * But runs one statement at a time.
# * But does not save the files. (once executed, it's gone).
# *
# * Also not suitable for bulk of code.

# %%
#now what we are writing in is a sort of TEXT-FILE
#SCRIPTING
#let us import,

import sys   #loading a library module
print('Library Module Loaded..!!')
# Out:
# Library Module Loaded..!!

# %%
# using module imported
# let's check the system we are using..

print(sys.platform)
# Out:
# win32

# %% [markdown]
# **Run just by Clicking?**
# * On Windows, Python program files show up as icons in file explorer windows and can
# automatically be run with a double-click of the mouse

# %%
#!!!!----CREATING INPUT FIELD----!!!!
input()
# Out:
# shahwar
# 'shahwar'

# %% [markdown]
# **Module?**
# * Every file of Python source code whose name ends in a .py extension
# is a module.
# * import is a statement.
# * import operations essentially load another file and grant access to that file’s contents.

# %% [markdown]
# **The IDLE User Interface**
# * IDLE = Integrated Development and Learning Environment.
# * In short, IDLE is a GUI that lets you edit, run, browse, and debug Python programs,
# all from a single interface.

# %% [markdown]
# **Python Object Types**
#
# Python programs
# can be decomposed into modules, statements, expressions, and objects, as follows:
# 1. Programs are composed of modules.
# 2. Modules contain statements.
# 3. Statements contain expressions.
# 4. Expressions create and process objects.

# %% [markdown]
# **Python’s Core Data Types**
# * ![Screenshot%20%28107%29.png](attachment:Screenshot%20%28107%29.png)

# %% [markdown]
# **Numbers**
# * Python’s core objects set includes the usual suspects: integers, floating-point numbers, and more exotic numeric types (complex numbers with imaginary parts) etc.

# %%
#!!!!----NUMBER SCRIPT TESTS----!!!!
123+555
# Out:
# 678

# %%
23 ** 8
# Out:
# 78310985281

# %%
1.26/2.4
# Out:
# 0.525

# %%
len(str(1000))
# Out:
# 4

# %%
len(str(2 ** 100))
# Out:
# 31

# %%
print(3.1415*2)
# Out:
# 6.283

# %%
3.1415*2
# Out:
# 6.283

# %%
import math  #evidently for math functions
math.pi
# Out:
# 3.141592653589793

# %%
math.sqrt(85)
# Out:
# 9.219544457292887

# %%
import random #for random num generation or selection
random.random()
# Out:
# 0.04774490020102917

# %%
random.choice([1,2,3])
# Out:
# 1

# %%
random.choice([1,2,3])
# Out:
# 2

# %%
random.choice([1,2,3])
# Out:
# 3

# %%
random.choice([1,2,3])
# Out:
# 2

# %% [markdown]
# **String**
# * Majorly deals with positional ordering among
# items.

# %%
str = 'alam'
len(str)
# Out:
# 4

# %%
#Indexing
str[0]
# Out:
# 'a'

# %%
str[1]
# Out:
# 'l'

# %%
str[2]
# Out:
# 'a'

# %%
str[3]
# Out:
# 'm'

# %%
str[-1] #from back starts with magnitude of 1
# Out:
# 'm'

# %%
str[-2]
# Out:
# 'a'

# %%
str[-3]
# Out:
# 'l'

# %%
str[-4]
# Out:
# 'a'

# %%
str
# Out:
# 'alam'

# %%
#Slicing
str[1:3]  # Slice of S from offsets 1 through 2 (not 3)
# Out:
# 'la'

# %%
str[1:]    # 1 to last
# Out:
# 'lam'

# %%
str[:3]    # everything but last
# Out:
# 'ala'

# %%
str[0:3]   # everything but last
# Out:
# 'ala'

# %%
str[0:-1]  # everything but last
# Out:
# 'ala'

# %%
str[:-1]    # everything but last
# Out:
# 'ala'

# %%
str[:]      # everything
# Out:
# 'alam'

# %%
#concatenating
str + 'naqvi'
# Out:
# 'alamnaqvi'

# %% [markdown]
# **Immutability**
# * For eg. You can’t change a string by assigning a char to one of its
# positions, but you can always build a new one and assign it to the same name.
# * Core types, numbers, strings, and tuples are immutable; lists and dictionaries are
# not.

# %%
str # original
# Out:
# 'alam'

# %%
str[0] = 'z' #throws ERROR //IMMUTABLE//Bcz Python erases old objects.
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [64], in <cell line: 1>()
# ----> 1 str[0] = 'z'
#
# TypeError: 'str' object does not support item assignment

# %%
str = 'z' + str[1:]
str
# Out:
# 'zlam'

# %%
# METHODS in STRINGS

str.find('la')
# Out:
# 1

# %%
str
# Out:
# 'zlam'

# %%
str.replace('zl','Al') # this change is temporary
# Out:
# 'Alam'

# %%
line = 'qyrus,quinnox,company'
line.split(',') #will give list of substrings
# Out:
# ['qyrus', 'quinnox', 'company']

# %%
str # originality continued
# Out:
# 'zlam'

# %%
str = str.replace('zl','Al')
str
# Out:
# 'Alam'

# %%
str # now Original is changes only when change is stored into the original object.
# Out:
# 'Alam'

# %%
str.upper()
# Out:
# 'ALAM'

# %%
str.isalpha()
# Out:
# True

# %%
# to remove WHITESPACE characters
line2 = 'aa,bb,cc,dd\n'
line2 = line2.rstrip()
line2
# Out:
# 'aa,bb,cc,dd'

# %%
# FORMATTING in STRING
line3 = '{0} eggs and {1} bananas'.format('TWO','THREE')
line3
# Out:
# 'TWO eggs and THREE bananas'

# %%
# Getting HELP about a method
help(str.replace)
# Out:
# Help on built-in function replace:
#
# replace(old, new, count=-1, /) method of builtins.str instance
#     Return a copy with all occurrences of substring old replaced by new.
#
#       count
#         Maximum number of occurrences to replace.
#         -1 (the default value) means replace all occurrences.
#
#     If the optional argument count is given, only the first count occurrences are
#     replaced.

# %% [markdown]
# **LISTS**
# * no fixed size
# * mutable

# %%
list = [123, 'spam', 1.23]
list
# Out:
# [123, 'spam', 1.23]

# %%
len(list)
# Out:
# 3

# %%
list[0]
# Out:
# 123

# %%
list[-1]
# Out:
# 1.23

# %%
list
# Out:
# [123, 'spam', 1.23]

# %%
# let us test MUTABILITY (upcoming approach will fail)
list + [4,5,6]
# Out:
# [123, 'spam', 1.23, 4, 5, 6]

# %%
list
# Out:
# [123, 'spam', 1.23]

# %%
list.append('4') # ran this 3 times so 3  times appending
list
# Out:
# [123, 'spam', 1.23, '4', '4', '4']

# %%
list
# Out:
# [123, 'spam', 1.23, '4', '4', '4']

# %%
list.pop(-1)
# Out:
# '4'

# %%
list
# Out:
# [123, 'spam', 1.23, '4', '4']

# %%
list.pop(3)
# Out:
# '4'

# %%
list
# Out:
# [123, 'spam', 1.23, '4']

# %%
list2 = ['bb','dd','aa','cc']
list2
# Out:
# ['bb', 'dd', 'aa', 'cc']

# %%
list2.sort()
list2
# Out:
# ['aa', 'bb', 'cc', 'dd']

# %%
list2.reverse()
list2
# Out:
# ['aa', 'bb', 'cc', 'dd']

# %%
# Bounds checking (expect an error 'out of range')
list2[99]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Input In [102], in <cell line: 2>()
#       1 # Bounds checking
# ----> 2 list2[99]
#
# IndexError: list index out of range

# %%
list2[0]
# Out:
# 'aa'

# %% [markdown]
# **NESTING (list)**

# %%
nested_list = [[1, 2, 3],[4, 5, 6], [7, 8, 9]]
nested_list
# Out:
# [[1, 2, 3], [4, 5, 6], [7, 8, 9]]

# %%
nested_list[1]
# Out:
# [4, 5, 6]

# %%
nested_list[1][2]
# Out:
# 6

# %% [markdown]
# **MATRIX LIST/NESTED-LIST/LIST COMPREHENSION**
# * A list comprehension expression, turns out to be a powerful
# way to process structures like our matrix.

# %%
nested_list #see this like a matrix
# Out:
# [[1, 2, 3], [4, 5, 6], [7, 8, 9]]

# %%
col1 = [row[0] for row in nested_list]
col1

# so basically the structure is,
# [result for i in list]
# Out:
# [1, 4, 7]

# %%
col2 = [row[1] for row in nested_list]
col2
# Out:
# [2, 5, 8]

# %%
col3 = [row[2] for row in nested_list]
col3
# Out:
# [3, 6, 9]

# %%
nested_list
# Out:
# [[1, 2, 3], [4, 5, 6], [7, 8, 9]]

# %%
[row[1] + 1 for row in nested_list] # Add 1 to each item in column 2
# Out:
# [3, 6, 9]

# %%
nested_list
# Out:
# [[1, 2, 3], [4, 5, 6], [7, 8, 9]]

# %%
[row[1] for row in nested_list if row[1] % 2 == 0] # Filter out odd items
# Out:
# [2, 8]

# %%
#getting DIAGONAL:

diag = [nested_list[i][i] for i in [0, 1, 2]] #made small index of list
diag

#Collect a diagonal from matrix
# Out:
# [1, 5, 9]

# %%
#Double each character

double_it = [i*2 for i in 'vatsal']
double_it
# Out:
# ['vv', 'aa', 'tt', 'ss', 'aa', 'll']

# %%
double_that = [i*2 for i in nested_list]
double_that
# Out:
# [[1, 2, 3, 1, 2, 3], [4, 5, 6, 4, 5, 6], [7, 8, 9, 7, 8, 9]]

# %%
nested_list[0]
# Out:
# [1, 2, 3]

# %%
double_this = [i*2 for i in nested_list[0]]
double_this
# Out:
# [2, 4, 6]

# %%
generator = (sum(row) for row in nested_list)
generator

# row elements ka sum
# Out:
# <generator object <genexpr> at 0x0000017860038CF0>

# %%
next(generator)
# Out:
# 6

# %% [markdown]
# **MAPPING-OPERATIONS**
# * basically dictionaries majorly

# %%
dict =  {'food': 'pizza', 'quantity': 4, 'color': 'yellow'}
dict
# Out:
# {'food': 'pizza', 'quantity': 4, 'color': 'yellow'}

# %%
#Fetch key value:

dict['food']
# Out:
# 'pizza'

# %%
dict['quantity']
# Out:
# 4

# %%
dict['quantity'] = dict['quantity'] + 1
dict
#manipulated the quantity.
#more you run the cell, more it will continue to increase.
# Out:
# {'food': 'pizza', 'quantity': 6, 'color': 'yellow'}

# %%
# Let's create KEYS by ASSIGNMENTS 

d={}
d['name']='Tony Stark'
d['role']='Iron Man'
d['job']='Save the World...!!!'

d
# Out:
# {'name': 'Tony Stark', 'role': 'Iron Man', 'job': 'Save the World...!!!'}

# %%
print(d)
# Out:
# {'name': 'Tony Stark', 'role': 'Iron Man', 'job': 'Save the World...!!!'}

# %%
#dictionary inside a dictionary
#for storing complex information

person_rec = {'name': {'first': 'Shahwar', 'last': 'Alam Naqvi'},
              'job': ['dev', 'mgr'],
              'age': 40.5}
person_rec
# Out:
# {'name': {'first': 'Shahwar', 'last': 'Alam Naqvi'},
#  'job': ['dev', 'mgr'],
#  'age': 40.5}

# %%
person_rec[0]  # error because no indexing in dictionary
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [51], in <cell line: 1>()
# ----> 1 person_rec[0]
#
# KeyError: 0

# %%
person_rec['name'] # key values would work definitely
# Out:
# {'first': 'Shahwar', 'last': 'Alam Naqvi'}

# %%
person_rec['job']
# Out:
# ['dev', 'mgr']

# %%
person_rec['age']
# Out:
# 40.5

# %%
# adding new value to a particular key

person_rec['job'].append('INTERN') #more u run the cell,more it repeats the addition
person_rec
# Out:
# {'name': {'first': 'Shahwar', 'last': 'Alam Naqvi'},
#  'job': ['dev', 'mgr', 'INTERN', 'INTERN', 'INTERN'],
#  'age': 40.5}

# %%
#This is the FLEXIBILITY of Python Core-Data-Types

# %%
# Dictionaries are UN-ORDERED.
#Meaning everytime different order of Key Value pairs will appear.

dict_unordered = {'a': 1, 'b': 2, 'c': 3}
dict_unordered
# Out:
# {'a': 1, 'b': 2, 'c': 3}

# %%
dict_unordered
# Out:
# {'a': 1, 'b': 2, 'c': 3}

# %%
dict_unordered
# Out:
# {'a': 1, 'b': 2, 'c': 3}

# %%
# getting the KEYS only
dict_unordered.keys()
# Out:
# dict_keys(['a', 'b', 'c'])

# %%
# get the above in list
list(dict_unordered.keys())
# Out:
# ['a', 'b', 'c']

# %%
D = {'a': 1, 'c': 3, 'b': 2, 'd':4}
D
# Out:
# {'a': 1, 'c': 3, 'b': 2, 'd': 4}

# %%
D.keys()
# Out:
# dict_keys(['a', 'c', 'b', 'd'])

# %%
# now lets get it in form of list

list(D.keys())
# Out:
# ['a', 'c', 'b', 'd']

# %%
# better to store the list

list_of_D = list(D.keys())
list_of_D
# Out:
# ['a', 'c', 'b', 'd']

# %%
# let us try sorting..
list_of_D.sort()
list_of_D
# Out:
# ['a', 'b', 'c', 'd']

# %%
sorted(D)
# Out:
# ['a', 'b', 'c', 'd']

# %%
D
# Out:
# {'a': 1, 'c': 3, 'b': 2, 'd': 4}

# %%
#inducing a bit of for loop here

for key in sorted(D):
    print(key,'=>',D[key])
# Out:
# a => 1
# b => 2
# c => 3
# d => 4

# %%
#printing CAPITAL and in different LINE
for c in 'naqvi':
    print(c.upper())
# Out:
# N
# A
# Q
# V
# I

# %%
# Inverted Half Right Triangle #PATTERN

n=5
while n>0:
    print('naqvi!' * n)
    n=n-1
# Out:
# naqvi!naqvi!naqvi!naqvi!naqvi!
# naqvi!naqvi!naqvi!naqvi!
# naqvi!naqvi!naqvi!
# naqvi!naqvi!
# naqvi!

# %%
# More COMPRESSIONS
sq_list = [1,2,3,4,5]
squares = [i**2 for i in sq_list]
squares
# Out:
# [1, 4, 9, 16, 25]

# %% [markdown]
# **What about Non-Existent Key?**
# * There are other ways to create dictionaries and avoid accessing nonexistent keys:
# _the get method_

# %%
D
# Out:
# {'a': 1, 'c': 3, 'b': 2, 'd': 4}

# %%
# this is how we deal with it,
value = D.get('x', 0) #x is not a key, instead a default key '0' is assigned
value
# Out:
# 0

# %%
#a simple case when the key and it's value is present.
present_val = D.get('a')
present_val
# Out:
# 1

# %% [markdown]
# **Tuples**

# %%
T = (1, 2, 3, 4)
len(T)
# Out:
# 4

# %%
T + (5,6,7,9) # Concatenation
# Out:
# (1, 2, 3, 4, 5, 6, 7, 9)

# %%
(3,4)+(11,12)
# Out:
# (3, 4, 11, 12)

# %%
T[0]
# Out:
# 1

# %%
T2 = ('naqvi',3.0,[11,22,33])
T2
# Out:
# ('naqvi', 3.0, [11, 22, 33])

# %%
T2[1]
# Out:
# 3.0

# %%
T2[0][2]
# Out:
# 'q'

# %%
T2[1] = 4.0 # item assignment not allowed, that's an advantage and disadvantage over List
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [48], in <cell line: 1>()
# ----> 1 T2[1] = 4.0
#
# TypeError: 'tuple' object does not support item assignment

# %%
T2.append(4)
T2    # we cannot APPEND in TUPLE
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [8], in <cell line: 1>()
# ----> 1 T2.append(4)
#       2 T2
#
# AttributeError: 'tuple' object has no attribute 'append'

# %% [markdown]
# **Why Tuples?**
# * Their IMMUTABILITY is the whole
# point. If you pass a collection of objects around your program as a list, it can be changed
# anywhere; if you use a tuple, it cannot.

# %% [markdown]
# **FILES**
# *  To create a file object, you call the built-in open function,
# passing in an external filename and a processing mode as strings.

# %%
# New File is created
f = open('data.txt', 'w') 
f
# see the file is created
# Out:
# <_io.TextIOWrapper name='data.txt' mode='w' encoding='cp1252'>

# %%
f.write('Shahwar\n')
f
# inside file it will be written
# Out:
# <_io.TextIOWrapper name='data.txt' mode='w' encoding='cp1252'>

# %% [markdown]
# ![Screenshot%20%28114%29.png](attachment:Screenshot%20%28114%29.png)

# %%
# close file
f.close()

# %%
f = open('data.txt') # 'r' is the default processing mode.
                     # by default in reading mode.
f
# Out:
# <_io.TextIOWrapper name='data.txt' mode='r' encoding='cp1252'>

# %%
# store file data into variable
text = f.read()
text     # ran two times, so dispalyed two times (the content of file)
# Out:
# 'Shahwar\nShahwar\n'

# %%
print(text)
# Out:
# Shahwar
# Shahwar

# %%
# To convert this output into list 
text.split()
# Out:
# ['Shahwar', 'Shahwar']

# %%
X = set('shahwar')
Y = {'n','a','q','v','i'}

# %%
X # dictionaries are unordered (proof)
# Out:
# {'a', 'h', 'r', 's', 'w'}

# %%
Y
# Out:
# {'a', 'i', 'n', 'q', 'v'}

# %%
#----INTERSECTION----#
X & Y
# Out:
# {'a'}

# %%
#----UNION----#
X | Y
# Out:
# {'a', 'h', 'i', 'n', 'q', 'r', 's', 'v', 'w'}

# %%
#---DIFFERENCE---#
X-Y
# Out:
# {'h', 'r', 's', 'w'}

# %%
# boolean

1>2
# Out:
# False

# %%
2>1
# Out:
# True

# %%
bool(1)
# Out:
# True

# %%
bool('san')
# Out:
# True

# %%
bool(0)
# Out:
# False

# %%
bool(-4)  # means other than 0 is TRUE
# Out:
# True

# %% [markdown]
# **User-Defined Classes**

# %%
class Worker:
    def __init__(self,name,pay):
        self.name = name
        self.pay = pay
        
    def lastName(self):
        return self.name.split()[-1]
    
    def giveRaise(self,percent):
        self.pay = self.pay * (1 + percent)
        return self.pay

# %%
#Let us make OBJECTS

bob = Worker('Bob Smith', 45000)
tony = Worker('Tony Stark', 56000)

# %%
bob.lastName()
# Out:
# 'Smith'

# %%
tony.lastName()
# Out:
# 'Stark'

# %%
bob.giveRaise(.10)
# Out:
# 49500.00000000001

# %% [markdown]
# ![Screenshot%20%28115%29.png](attachment:Screenshot%20%28115%29.png)

# %% [markdown]
# **Sets**
# * Sets are collections that are unordered and mutable. However, every item in a set much be unique.

# %%
the_text = "Hemanth Artificial Intelligence"
set(the_text)
# Out:
# {' ',
#  'A',
#  'H',
#  'I',
#  'a',
#  'c',
#  'e',
#  'f',
#  'g',
#  'h',
#  'i',
#  'l',
#  'm',
#  'n',
#  'r',
#  't'}

# %%
print(set(the_text)) # print ALIGNS a bit
# Out:
# {'l', 'f', 'c', 'e', ' ', 'n', 'a', 'A', 'i', 'g', 'r', 'H', 't', 'h', 'I', 'm'}

# %%
print(set(the_text.split(" ")))
# Out:
# {'Hemanth', 'Intelligence', 'Artificial'}

# %% [markdown]
# ![Screenshot%20%28116%29.png](attachment:Screenshot%20%28116%29.png)

# %% [markdown]
# **IF-STATEMENT**

# %%
# If statement
x = 4
if x < 1:
    score = "low"
elif x <= 4: # elif = else if
    score = "medium"
else:
    score = "high"
print (score)
# Out:
# medium

# %% [markdown]
# * **PYTHON LAMBDA**
#
# * A lambda function is a small anonymous function.
#
# * A lambda function can take any number of arguments, but can only have one expression.
#
# * Syntax
#  : _lambda arguments : expression_

# %%
x = lambda a, b, c : a + b + c
x(5, 6, 2)
# Out:
# 13
